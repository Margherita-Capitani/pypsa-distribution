# %%
from ramp import UseCase, User
import pandas as pd
import json
from collections import Counter

# %% [markdown]
# ### CURCH USERS:

# %%
Church = User(
    user_name="Church",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# ADD APPLIANCE:

# INDOOR_BULB
indoor_bulb = Church.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=10,  # how many indoor_bulb each household type 1 has
    power=26,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=180,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=60,
    fixed="no",
    flat="no",
    window_1=[1200, 1440],  # from 8 PM to 00 pM
    random_var_w=0.35,
)


# OUTDOOR_BULB
outdoor_bulb = Church.add_appliance(
    name="outdoor_bulb",  # optional feature for the appliance class
    number=7,  # how many outdoor_bulbeach household type 1 has
    power=26,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=60,
    fixed="yes",
    flat="yes",
    window_1=[1200, 1440],  # from 8 PM to 00 pM
    random_var_w=0.35,
)

# SPEAKER:
speaker = Church.add_appliance(
    name="speaker",  # optional feature for the appliance class
    number=1,  # how many speakereach household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=60,
    fixed="no",
    flat="no",
    window_1=[480, 720],  # from 8 AM to 12 AM
    window_2=[960, 1080],  # from 16 PM to 18 pM
    window_3=[1200, 1320],  # from 2O PM to 22 pM
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Church"
path1 = base_dir1 + "/data/ramp/Church.xslx"
use_case = UseCase(users=[Church])

use_case.save(path)

# %% [markdown]
# # SCHOOL USER:

# %%
School = User(
    user_name="School",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# ADD APPLIANCE:

# INDOOR_BULB
indoor_bulb = School.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=8,  # how many indoor_bulb each household type 1 has
    power=40,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=1,  # how many time-windows the appliance is used in
    func_time=60,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[1200, 1440],  # from 8 PM to 00 pM
    random_var_w=0.35,
)

# OUTDOOR_BULB
outdoor_bulb = School.add_appliance(
    name="outdoor_bulb",  # optional feature for the appliance class
    number=6,  # how many outdoor_bulb each household type 1 has
    power=40,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[1200, 1440],  # from 8 PM to 00 pM
    random_var_w=0.35,
)
# PHONE CHARGER
phone_charger = School.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=5,  # how many phone_charger each household type 1 has
    power=18,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=120,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[480, 1080],  # from 8 PM to 00 pM
    random_var_w=0.35,
)
# PC:
pc = School.add_appliance(
    name="pc",  # optional feature for the appliance class
    number=18,  # how many pc each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[510, 750],  # from 8.30 AM to 12:30 pM
    window_2=[810, 1080],  # from 8 AM to 12 AM
    random_var_w=0.35,
)
# PRINTER:
printer = School.add_appliance(
    name="printer",  # optional feature for the appliance class
    number=1,  # how many printer each household type 1 has
    power=20,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=210,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[510, 750],  # from 8.30 AM to 12:30 aM
    window_2=[810, 1080],  # from 1:30 pM to 6 AM
    random_var_w=0.35,
)
# FREEZER:
freezer = School.add_appliance(
    name="freezer",  # optional feature for the appliance class
    number=1,  # how many freezer each household type 1 has
    power=200,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,
    window_1=[0, 1440],  # from 00:00 AM to 00:00 aM
)
freezer.specific_cycle_1(200, 20, 5, 10)
freezer.specific_cycle_2(200, 15, 5, 15)
freezer.specific_cycle_3(200, 10, 5, 20)
freezer.cycle_behaviour([580, 1200], [0, 0], [510, 579], [0, 0], [0, 509], [1201, 1440])

# TV:
tv = School.add_appliance(
    name="tv",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=120,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=30,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[510, 750],  # from 8.30 AM to 12:30 aM
    window_2=[810, 1080],  # from 1:30 pM to 6 AM
    random_var_w=0.35,
)

# TV:
dvd = School.add_appliance(
    name="dvd",  # optional feature for the appliance class
    number=1,  # how many dvd each household type 1 has
    power=60,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=120,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=30,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[510, 750],  # from 8.30 AM to 12:30 aM
    window_2=[810, 1080],  # from 1:30 pM to 6 AM
    random_var_w=0.35,
)

# STEREO:
stereo = School.add_appliance(
    name="stereo",  # optional feature for the appliance class
    number=1,  # how many stereo each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=90,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[510, 750],  # from 8.30 AM to 12:30 aM
    window_2=[810, 1080],  # from 1:30 pM to 6 AM
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/School"
path1 = base_dir1 + "/data/ramp/School.xslx"
use_case = UseCase(users=[Church])

use_case.save(path)

# %% [markdown]
# #### HOSPITAL:

# %%
Hospital = User(
    user_name="Hospital",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
indoor_bulb = Hospital.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=12,  # how many indoor_bulb each household type 1 has
    power=40,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=690,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[480, 720],  # from 7:00 aM to 12:00 aM
    window_2=[870, 1440],  # from 2:30 pM to 00:00 pM
    random_var_w=0.35,
)
# OUTDOOR_BULB
outdoor_bulb = Hospital.add_appliance(
    name="outdoor_bulb",  # optional feature for the appliance class
    number=4,  # how many outdoor_bulb each household type 1 has
    power=40,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=690,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[0, 480],  # from 00:00 aM to 8:00 aM
    window_2=[1200, 1440],  # from 8:00 pM to 00:00 pM
    random_var_w=0.35,
)
# PHONE CHARGER
phone_charger = Hospital.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=8,  # how many phone_charger each household type 1 has
    power=18,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=300,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=30,
    fixed="no",
    flat="no",
    window_1=[0, 1440],  # from 8 aM to 12:00 aM
    random_var_w=0.35,
)
# FRIDGE:
fridge = Hospital.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=250,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,
    window_1=[0, 1440],  # from 00:00 AM to 00:00 aM
)
fridge.specific_cycle_1(200, 20, 5, 10)
fridge.specific_cycle_2(200, 15, 5, 15)
fridge.specific_cycle_3(200, 10, 5, 20)
fridge.cycle_behaviour([580, 1200], [0, 0], [420, 579], [0, 0], [0, 419], [1201, 1440])

fridge2 = Hospital.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=250,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,
    window_1=[0, 1440],  # from 00:00 AM to 00:00 aM
)
fridge.specific_cycle_1(150, 20, 5, 10)
fridge.specific_cycle_2(150, 15, 5, 15)
fridge.specific_cycle_3(150, 10, 5, 20)
fridge.cycle_behaviour([580, 1200], [0, 0], [420, 579], [0, 0], [0, 299], [1201, 1440])

fridge = Hospital.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=250,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,
    window_1=[0, 1440],  # from 00:00 AM to 00:00 aM
)
fridge.specific_cycle_1(150, 20, 5, 10)
fridge.specific_cycle_2(150, 15, 5, 15)
fridge.specific_cycle_3(150, 10, 5, 20)
fridge.cycle_behaviour([580, 1200], [0, 0], [420, 479], [0, 0], [0, 419], [1201, 1440])

# PC:
pc = Hospital.add_appliance(
    name="pc",  # optional feature for the appliance class
    number=2,  # how many pc each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=300,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[480, 720],  # from 8.30 AM to 12:30 pM
    window_2=[1050, 1440],  # from 8 AM to 12 AM
    random_var_w=0.35,
)

mixer = Hospital.add_appliance(
    name="mixer",  # optional feature for the appliance class
    number=1,  # how many mixer each household type 1 has
    power=50,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    occasional_use=0.33,
    fixed="no",
    flat="no",
    window_1=[480, 720],  # from 8.30 AM to 12:30 pM
    window_2=[1050, 1440],  # from 8 AM to 12 AM
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Hospital"
path1 = base_dir1 + "/data/ramp/Hospital.xslx"
use_case = UseCase(users=[Church])

use_case.save(path)

# %% [markdown]
# ### TIER 1:

# %% [markdown]
# Ore diurne: minimo 4
# Ore serali: minimo 1
# Potenza massima: fra 3 e 50 W
# Dispositivi: task lighiting - phone charger
# Energia giornaliera: almeno 12 Wh

# %%
Tier1 = User(
    user_name="Tier1",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
Task_lighiting = Tier1.add_appliance(
    name="Task_lighiting",  # optional feature for the appliance class
    number=2,  # how many indoor_bulb each household type 1 has
    power=11,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=1,  # how many time-windows the appliance is used in
    func_time=180,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[1140, 1320],  # from 19:00 to 22:00
    random_var_w=0.35,
)

# PHONE CHARGER
phone_charger = Tier1.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=1,  # how many phone_charger each household type 1 has
    power=5,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    window_1=[360, 540],  # from 6:00 to 8:00
    window_2=[1140, 1320],  # from 19:00 to 22:00
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Tier1"
path1 = base_dir1 + "/data/ramp/Tier1.xslx"
use_case = UseCase(users=[Tier1])

use_case.save(path)

# %% [markdown]
# ### TIER 2:

# %% [markdown]
# Ore diurne: minimo 4
# Ore serali: minimo 2
# Potenza massima: fra 50 e 200 W
# Dispositivi: Multipoint general lighting - phone charger - Television - Pc - Printer

# %%
Tier2 = User(
    user_name="Tier2",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
indoor_bulb = Tier2.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=3,  # how many indoor_bulb each household type 1 has
    power=13,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=240,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[360, 480],  # from 6:00 to 9:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# PHONE CHARGER
phone_charger = Tier2.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=2,  # how many phone_charger each household type 1 has
    power=5,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# TV:
tv = Tier2.add_appliance(
    name="tv",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=90,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# FAN:
fan = Tier2.add_appliance(
    name="fan",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=35,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=180,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.6,
    window_1=[360, 600],  # from 6:00 to 10:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

# RADIO:
radio = Tier2.add_appliance(
    name="radio",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=30,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=90,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_3=[720, 840],  # from 12:00 to 14:00
    window_2=[1080, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Tier2"
path1 = base_dir1 + "/data/ramp/Tier2.xslx"
use_case = UseCase(users=[Tier2])

use_case.save(path)

# %% [markdown]
# ### TIER 3:

# %%
Tier3 = User(
    user_name="Tier3",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
indoor_bulb = Tier3.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=4,  # how many indoor_bulb each household type 1 has
    power=13,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=240,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[360, 480],  # from 6:00 to 8:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# PHONE CHARGER
phone_charger = Tier3.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=2,  # how many phone_charger each household type 1 has
    power=5,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# TV:
tv = Tier3.add_appliance(
    name="tv",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=120,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1080, 1380],  # from 18:00 to 23:00
    random_var_w=0.35,
)

# FAN:
air_cooler = Tier3.add_appliance(
    name="air_cooler",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.6,
    window_1=[360, 600],  # from 6:00 to 10:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

radio = Tier3.add_appliance(
    name="radio",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=30,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=120,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_3=[720, 840],  # from 12:00 to 14:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

blender = Tier3.add_appliance(
    name="blender",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=600,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=10,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.3,
    window_1=[1080, 1260],  # from 18:00 to 21:00
    random_var_w=0.35,
)

fridge = Tier3.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,  # Tipi di funzionamento del dispositivo
    window_1=[0, 1440],  # 24h
)
fridge.specific_cycle_1(100, 10, 5, 20)
fridge.specific_cycle_2(100, 15, 5, 15)
fridge.specific_cycle_3(100, 20, 5, 10)
fridge.cycle_behaviour(
    cw11=[0, 299], cw12=[1201, 1440], cw21=[300, 479], cw31=[480, 1200]
)


base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Tier3"
path1 = base_dir1 + "/data/ramp/Tier3.xslx"
use_case = UseCase(users=[Tier3])

use_case.save(path)

# %% [markdown]
# #### TIER 4:

# %%
Tier4 = User(
    user_name="Tier4",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
indoor_bulb = Tier4.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=6,  # how many indoor_bulb each household type 1 has
    power=13,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=240,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[360, 480],  # from 6:00 to 8:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# PHONE CHARGER
phone_charger = Tier4.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=3,  # how many phone_charger each household type 1 has
    power=5,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1140, 1440],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# TV:
tv = Tier4.add_appliance(
    name="tv",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1020, 1380],  # from 17:00 to 23:00
    random_var_w=0.35,
)

# FAN:
air_cooler = Tier4.add_appliance(
    name="air_cooler",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.6,
    window_1=[360, 600],  # from 6:00 to 10:00
    window_2=[1020, 1320],  # from 17:00 to 22:00
    random_var_w=0.35,
)

radio = Tier4.add_appliance(
    name="radio",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=30,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 8:00
    window_3=[720, 960],  # from 12:00 to 14:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

blender = Tier4.add_appliance(
    name="blender",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=600,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=10,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.3,
    window_1=[1080, 1260],  # from 18:00 to 21:00
    random_var_w=0.35,
)

iron_box = Tier4.add_appliance(
    name="iron_box",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=30,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.2,
    window_1=[420, 540],  # from 8:00 to 9:00
    window_2=[1020, 1080],  # from 17:00 to 18:00
    random_var_w=0.35,
)

electric_ketle = Tier4.add_appliance(
    name="electric_ketle",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1200,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=15,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=3,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

pressure_cooker = Tier4.add_appliance(
    name="pressure_cooker",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1350,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=30,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[1080, 1200],  # from 18:00 to 20:00
    random_var_w=0.35,
)

fridge = Tier4.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,  # Tipi di funzionamento del dispositivo
    window_1=[0, 1440],  # 24h
)
fridge.specific_cycle_1(150, 10, 5, 20)
fridge.specific_cycle_2(150, 15, 5, 15)
fridge.specific_cycle_3(150, 20, 5, 10)
fridge.cycle_behaviour(
    cw11=[0, 299], cw12=[1201, 1440], cw21=[300, 479], cw31=[480, 1200]
)

# PC:
pc = Tier4.add_appliance(
    name="pc",  # optional feature for the appliance class
    number=1,  # how many pc each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=180,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.3,
    window_1=[480, 720],  # from 8:00 to 12:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Tier4"
path1 = base_dir1 + "/data/ramp/Tier4.xslx"
use_case = UseCase(users=[Tier4])

use_case.save(path)

# %% [markdown]
# ### TIER 5

# %%
Tier5 = User(
    user_name="Tier5",  # an optional feature for the User class
    num_users=100,  # Specifying the number of specific user category in the community
)

# INDOOR_BULB
indoor_bulb = Tier5.add_appliance(
    name="indoor_bulb",  # optional feature for the appliance class
    number=7,  # how many indoor_bulb each household type 1 has
    power=13,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    num_windows=2,  # how many time-windows the appliance is used in
    func_time=240,  # Total functioning time of appliance in minutes
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    window_1=[360, 480],  # from 6:00 to 8:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# PHONE CHARGER
phone_charger = Tier5.add_appliance(
    name="phone_charger",  # optional feature for the appliance class
    number=3,  # how many phone_charger each household type 1 has
    power=5,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=60,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.20,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1140, 1440],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# TV:
tv = Tier5.add_appliance(
    name="tv",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_3=[720, 960],  # from 12:00 to 14:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

# FAN:
air_cooler = Tier5.add_appliance(
    name="air_cooler",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.6,
    window_1=[360, 600],  # from 6:00 to 10:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

radio = Tier5.add_appliance(
    name="radio",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=30,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=240,  # Total functioning time of appliance in minutes
    num_windows=3,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.8,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_3=[720, 960],  # from 12:00 to 14:00
    window_2=[1140, 1380],  # from 19:00 to 23:00
    random_var_w=0.35,
)

blender = Tier5.add_appliance(
    name="blender",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=600,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=10,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.3,
    window_1=[1080, 1260],  # from 18:00 to 21:00
    random_var_w=0.35,
)

iron_box = Tier5.add_appliance(
    name="iron_box",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1100,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=30,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.2,
    window_1=[420, 540],  # from 8:00 to 9:00
    window_2=[1020, 1080],  # from 17:00 to 18:00
    random_var_w=0.35,
)

electric_ketle = Tier5.add_appliance(
    name="electric_ketle",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1200,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=15,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=3,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[360, 540],  # from 6:00 to 9:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

pressure_cooker = Tier5.add_appliance(
    name="pressure_cooker",  # optional feature for the appliance class
    number=1,  # how many tv each household type 1 has
    power=1350,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=30,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=5,
    fixed="no",
    flat="no",
    occasional_use=0.5,
    window_1=[1080, 1200],  # from 18:00 to 20:00
    random_var_w=0.35,
)

fridge = Tier5.add_appliance(
    name="fridge",  # optional feature for the appliance class
    number=1,  # how many fridge each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=1440,  # Total functioning time of appliance in minutes
    num_windows=1,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0,  # randomization of total utilization time
    func_cycle=30,
    fixed="yes",
    flat="no",
    fixed_cycle=3,  # Tipi di funzionamento del dispositivo
    window_1=[0, 1440],  # 24h
)
fridge.specific_cycle_1(150, 10, 5, 20)
fridge.specific_cycle_2(150, 15, 5, 15)
fridge.specific_cycle_3(150, 20, 5, 10)
fridge.cycle_behaviour(
    cw11=[0, 299], cw12=[1201, 1440], cw21=[300, 479], cw31=[480, 1200]
)

# PC:
pc = Tier5.add_appliance(
    name="pc",  # optional feature for the appliance class
    number=1,  # how many pc each household type 1 has
    power=150,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=180,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.3,
    window_1=[480, 720],  # from 8:00 to 12:00
    window_2=[1080, 1320],  # from 18:00 to 22:00
    random_var_w=0.35,
)

oven = Tier5.add_appliance(
    name="oven",  # optional feature for the appliance class
    number=1,  # how many pc each household type 1 has
    power=1350,  # RAMP does not take care of units of measure (e.g., Watts), you must be consistent
    func_time=30,  # Total functioning time of appliance in minutes
    num_windows=2,  # how many time-windows the appliance is used in
    time_fraction_random_variability=0.10,  # randomization of total utilization time
    func_cycle=10,
    fixed="no",
    flat="no",
    occasional_use=0.6,
    window_1=[600, 840],  # from 10:00 to 14:00
    window_2=[1020, 1260],  # from 18:00 to 21:00
    random_var_w=0.35,
)


base_dir1 = "C:/Users/margh/Desktop/pypsa/pypsa-distribution"  # Edit this string with the top of the path where you saved the pypsa-distribution folder
path = base_dir1 + "/data/ramp/Tier5"
path1 = base_dir1 + "/data/ramp/Tier5.xslx"
use_case = UseCase(users=[Tier5])

use_case.save(path)
